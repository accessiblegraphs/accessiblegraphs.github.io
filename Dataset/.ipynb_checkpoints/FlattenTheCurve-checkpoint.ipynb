# %% [markdown]
# # Generating Data for Flatten the Curve

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
from scipy.stats import norm

# %% [markdown]
# ## Generate and Plot Data

# %%
# Constants for withMeasures 
mu_wm = 0.54
sigma_wm = 0.25
ub_wm = 1  #upper bound
lb_wm = 0  #lower bound
x_wm = np.arange(lb_wm, ub_wm, 0.01)
y_wm = norm(mu_wm, sigma_wm)

# Constants for atCapacity 
mu_ac = 0.28
sigma_ac = 0.09
ub_ac = 0.6
lb_ac = 0
x_ac = np.arange(lb_ac, ub_ac, 0.01)
y_ac = norm(mu_ac, sigma_ac)

# Horizontal line
x_hor = np.arange(0, 1, 0.01)
y_hor = np.ones(len(x_hor)) * 1.65

# %%
plt.plot(x_wm, y_wm.pdf(x_wm))
plt.plot(x_ac, y_ac.pdf(x_ac))
# plt.hlines(1.65, 0, 1, 'k', 'dashed')
plt.plot(x_hor, y_hor,"--")
plt.show()

# %% [markdown]
# ## Export Data

# %%
# data = np.asarray([x_wm, y_wm, x_ac, y_ac, x_hor, y_hor])
# data = np.transpose(data)
# print(x_wm)
data = np.concatenate((x_wm, y_wm.pdf(x_wm), x_ac, y_ac.pdf(x_ac), x_hor, y_hor))
data.size

# data = np.transpose(data)
# print(size(data))
# np.savetxt('flattenTheCurve.csv', data, delimiter=",")
# numpy.savetxt("foo.csv", a, delimiter=",")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-130-8646f0dfecbd> in <module>
#       6
#       7 # data = np.transpose(data)
# ----> 8 print(size(data))
#       9 # np.savetxt('flattenTheCurve.csv', data, delimiter=",")
#      10 # numpy.savetxt("foo.csv", a, delimiter=",")
#
# NameError: name 'size' is not defined
